# %% [markdown]
# ### **1. Import the Required Libraries**

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from tensorflow import keras
from tensorflow.keras import layers
import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# ### **2. Load the Image Training and Validation Datasets**

# %% [markdown]
# #### **i. Get the Image Dataset Paths**

# %%
train_dataset_path = '/kaggle/input/pothole-data/My_Dataset/train/'
validation_dataset_path = '/kaggle/input/pothole-data/My_Dataset/test/'

# %% [markdown]
# #### **ii. Load Image Datasets and Apply Augmentations**

# %% [markdown]
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32
image_size = (128,128)

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 5075 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 1021 images belonging to 2 classes.

# %% [markdown]
# #### **iii. Get the Label Mappings**

# %% [markdown]
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Plain
# 1 : Pothole

# %% [markdown]
# ### **3. Plotting Sample Training Images**

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ### **4. Training a VGG16 Model**

# %% [markdown]
# Since the training dataset is ready let's create a simple VGG19 Model to train on the image datasets

# %% [markdown]
# #### **i. Create a VGG19 Build Model**

# %%
base_model = keras.applications.VGG19(include_top=False,input_shape=image_size+(3,))
base_model.trainable = False

model = keras.Sequential([
    base_model,
    layers.Flatten(),
    layers.Dense(2,activation='sigmoid')
])

model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.BinaryCrossentropy(),
    metrics=[keras.metrics.BinaryAccuracy()]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 2)                 16386
#
# =================================================================
# Total params: 20,040,770
# Trainable params: 16,386
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, expand_nested=True, show_shapes=True, show_layer_names=False)

# %% [markdown]
# #### **ii. Defining Callbacks**

# %% [markdown]
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)

# %% [markdown]
# #### **a. Reduce Learning Rate on Plateau**
#
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %% [markdown]
# #### **iii. Defining the Optimizer**

# %%
optimizer = Adam(learning_rate=0.0001)

# %% [markdown]
# #### **iv. Compile the Model**

# %%
model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %% [markdown]
# #### **v. Training the Model**

# %%
# training
history = model.fit(train_generator,batch_size=32,epochs=50,
        validation_data=validation_generator,verbose=2, callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 159/159 - 149s - loss: 0.2242 - accuracy: 0.9478 - val_loss: 0.3442 - val_accuracy: 0.8384 - lr: 1.0000e-04 - 149s/epoch - 938ms/step
# Epoch 2/50
# 159/159 - 69s - loss: 0.0827 - accuracy: 0.9803 - val_loss: 0.3420 - val_accuracy: 0.8550 - lr: 1.0000e-04 - 69s/epoch - 434ms/step
# Epoch 3/50
# 159/159 - 68s - loss: 0.0614 - accuracy: 0.9846 - val_loss: 0.3281 - val_accuracy: 0.8697 - lr: 1.0000e-04 - 68s/epoch - 427ms/step
# Epoch 4/50
# 159/159 - 69s - loss: 0.0486 - accuracy: 0.9868 - val_loss: 0.3004 - val_accuracy: 0.8815 - lr: 1.0000e-04 - 69s/epoch - 432ms/step
# Epoch 5/50
# 159/159 - 69s - loss: 0.0386 - accuracy: 0.9907 - val_loss: 0.3059 - val_accuracy: 0.8805 - lr: 1.0000e-04 - 69s/epoch - 436ms/step
# Epoch 6/50
# 159/159 - 69s - loss: 0.0383 - accuracy: 0.9880 - val_loss: 0.3158 - val_accuracy: 0.8766 - lr: 1.0000e-04 - 69s/epoch - 434ms/step
# Epoch 7/50
# 159/159 - 69s - loss: 0.0331 - accuracy: 0.9911 - val_loss: 0.2881 - val_accuracy: 0.8883 - lr: 1.0000e-04 - 69s/epoch - 431ms/step
# Epoch 8/50
# 159/159 - 68s - loss: 0.0283 - accuracy: 0.9921 - val_loss: 0.3199 - val_accuracy: 0.8805 - lr: 1.0000e-04 - 68s/epoch - 431ms/step
# Epoch 9/50
# 159/159 - 69s - loss: 0.0267 - accuracy: 0.9923 - val_loss: 0.2702 - val_accuracy: 0.9060 - lr: 1.0000e-04 - 69s/epoch - 432ms/step
# Epoch 10/50
# 159/159 - 69s - loss: 0.0270 - accuracy: 0.9931 - val_loss: 0.2784 - val_accuracy: 0.9060 - lr: 1.0000e-04 - 69s/epoch - 434ms/step
# Epoch 11/50
# 159/159 - 69s - loss: 0.0253 - accuracy: 0.9935 - val_loss: 0.2982 - val_accuracy: 0.8942 - lr: 1.0000e-04 - 69s/epoch - 434ms/step
# Epoch 12/50
# 159/159 - 70s - loss: 0.0233 - accuracy: 0.9943 - val_loss: 0.2513 - val_accuracy: 0.9167 - lr: 1.0000e-04 - 70s/epoch - 441ms/step
# Epoch 13/50
# 159/159 - 69s - loss: 0.0246 - accuracy: 0.9927 - val_loss: 0.3096 - val_accuracy: 0.8962 - lr: 1.0000e-04 - 69s/epoch - 434ms/step
# Epoch 14/50
# 159/159 - 69s - loss: 0.0210 - accuracy: 0.9945 - val_loss: 0.2404 - val_accuracy: 0.9216 - lr: 1.0000e-04 - 69s/epoch - 436ms/step
# Epoch 15/50
# 159/159 - 70s - loss: 0.0184 - accuracy: 0.9943 - val_loss: 0.2781 - val_accuracy: 0.9070 - lr: 1.0000e-04 - 70s/epoch - 439ms/step
# Epoch 16/50
# 159/159 - 70s - loss: 0.0197 - accuracy: 0.9939 - val_loss: 0.2455 - val_accuracy: 0.9187 - lr: 1.0000e-04 - 70s/epoch - 439ms/step
# Epoch 17/50
# 159/159 - 69s - loss: 0.0169 - accuracy: 0.9955 - val_loss: 0.2282 - val_accuracy: 0.9246 - lr: 1.0000e-04 - 69s/epoch - 433ms/step
# Epoch 18/50
# 159/159 - 70s - loss: 0.0193 - accuracy: 0.9945 - val_loss: 0.2732 - val_accuracy: 0.9138 - lr: 1.0000e-04 - 70s/epoch - 439ms/step
# Epoch 19/50
# 159/159 - 69s - loss: 0.0179 - accuracy: 0.9945 - val_loss: 0.2620 - val_accuracy: 0.9187 - lr: 1.0000e-04 - 69s/epoch - 433ms/step
# Epoch 20/50
# 159/159 - 68s - loss: 0.0149 - accuracy: 0.9953 - val_loss: 0.2621 - val_accuracy: 0.9187 - lr: 1.0000e-04 - 68s/epoch - 429ms/step
# Epoch 21/50
# 159/159 - 69s - loss: 0.0189 - accuracy: 0.9945 - val_loss: 0.3178 - val_accuracy: 0.9040 - lr: 1.0000e-04 - 69s/epoch - 431ms/step
# Epoch 22/50
# 159/159 - 69s - loss: 0.0176 - accuracy: 0.9945 - val_loss: 0.2934 - val_accuracy: 0.9089 - lr: 1.0000e-04 - 69s/epoch - 436ms/step
# Epoch 23/50
# 159/159 - 70s - loss: 0.0155 - accuracy: 0.9955 - val_loss: 0.2704 - val_accuracy: 0.9177 - lr: 3.1623e-05 - 70s/epoch - 440ms/step
# Epoch 24/50
# 159/159 - 70s - loss: 0.0139 - accuracy: 0.9959 - val_loss: 0.2845 - val_accuracy: 0.9119 - lr: 3.1623e-05 - 70s/epoch - 442ms/step
# Epoch 25/50
# 159/159 - 70s - loss: 0.0145 - accuracy: 0.9959 - val_loss: 0.2803 - val_accuracy: 0.9128 - lr: 3.1623e-05 - 70s/epoch - 443ms/step
# Epoch 26/50
# 159/159 - 70s - loss: 0.0143 - accuracy: 0.9963 - val_loss: 0.2359 - val_accuracy: 0.9285 - lr: 3.1623e-05 - 70s/epoch - 439ms/step
# Epoch 27/50
# 159/159 - 71s - loss: 0.0115 - accuracy: 0.9982 - val_loss: 0.2837 - val_accuracy: 0.9099 - lr: 3.1623e-05 - 71s/epoch - 446ms/step
# Epoch 28/50
# 159/159 - 70s - loss: 0.0134 - accuracy: 0.9970 - val_loss: 0.2640 - val_accuracy: 0.9207 - lr: 1.0000e-05 - 70s/epoch - 438ms/step
# Epoch 29/50
# 159/159 - 69s - loss: 0.0146 - accuracy: 0.9968 - val_loss: 0.2689 - val_accuracy: 0.9177 - lr: 1.0000e-05 - 69s/epoch - 436ms/step
# Epoch 30/50
# 159/159 - 69s - loss: 0.0145 - accuracy: 0.9957 - val_loss: 0.2555 - val_accuracy: 0.9216 - lr: 1.0000e-05 - 69s/epoch - 434ms/step
# Epoch 31/50
# 159/159 - 69s - loss: 0.0131 - accuracy: 0.9965 - val_loss: 0.2599 - val_accuracy: 0.9207 - lr: 1.0000e-05 - 69s/epoch - 435ms/step
# Epoch 32/50
# 159/159 - 70s - loss: 0.0141 - accuracy: 0.9967 - val_loss: 0.2550 - val_accuracy: 0.9226 - lr: 1.0000e-05 - 70s/epoch - 438ms/step
# Epoch 33/50
# 159/159 - 69s - loss: 0.0127 - accuracy: 0.9967 - val_loss: 0.2552 - val_accuracy: 0.9226 - lr: 3.1623e-06 - 69s/epoch - 435ms/step
# Epoch 34/50
# 159/159 - 69s - loss: 0.0120 - accuracy: 0.9968 - val_loss: 0.2611 - val_accuracy: 0.9207 - lr: 3.1623e-06 - 69s/epoch - 434ms/step
# Epoch 35/50
# 159/159 - 69s - loss: 0.0131 - accuracy: 0.9963 - val_loss: 0.2610 - val_accuracy: 0.9207 - lr: 3.1623e-06 - 69s/epoch - 432ms/step
# Epoch 36/50
# 159/159 - 69s - loss: 0.0147 - accuracy: 0.9953 - val_loss: 0.2604 - val_accuracy: 0.9207 - lr: 3.1623e-06 - 69s/epoch - 432ms/step
# Epoch 37/50
# 159/159 - 69s - loss: 0.0135 - accuracy: 0.9972 - val_loss: 0.2599 - val_accuracy: 0.9207 - lr: 3.1623e-06 - 69s/epoch - 434ms/step
# Epoch 38/50
# 159/159 - 69s - loss: 0.0128 - accuracy: 0.9968 - val_loss: 0.2593 - val_accuracy: 0.9216 - lr: 1.0000e-06 - 69s/epoch - 436ms/step
# Epoch 39/50
# 159/159 - 70s - loss: 0.0130 - accuracy: 0.9963 - val_loss: 0.2593 - val_accuracy: 0.9216 - lr: 1.0000e-06 - 70s/epoch - 442ms/step
# Epoch 40/50
# 159/159 - 70s - loss: 0.0131 - accuracy: 0.9970 - val_loss: 0.2616 - val_accuracy: 0.9207 - lr: 1.0000e-06 - 70s/epoch - 441ms/step
# Epoch 41/50
# 159/159 - 70s - loss: 0.0145 - accuracy: 0.9955 - val_loss: 0.2601 - val_accuracy: 0.9207 - lr: 1.0000e-06 - 70s/epoch - 438ms/step
# Epoch 42/50
# 159/159 - 69s - loss: 0.0142 - accuracy: 0.9961 - val_loss: 0.2599 - val_accuracy: 0.9207 - lr: 1.0000e-06 - 69s/epoch - 433ms/step
# Epoch 43/50
# 159/159 - 69s - loss: 0.0136 - accuracy: 0.9965 - val_loss: 0.2605 - val_accuracy: 0.9207 - lr: 3.1623e-07 - 69s/epoch - 434ms/step
# Epoch 44/50
# 159/159 - 69s - loss: 0.0143 - accuracy: 0.9953 - val_loss: 0.2603 - val_accuracy: 0.9207 - lr: 3.1623e-07 - 69s/epoch - 432ms/step
# Epoch 45/50
# 159/159 - 70s - loss: 0.0151 - accuracy: 0.9955 - val_loss: 0.2603 - val_accuracy: 0.9207 - lr: 3.1623e-07 - 70s/epoch - 438ms/step
# Epoch 46/50
# 159/159 - 69s - loss: 0.0124 - accuracy: 0.9970 - val_loss: 0.2606 - val_accuracy: 0.9207 - lr: 3.1623e-07 - 69s/epoch - 434ms/step
# Epoch 47/50
# 159/159 - 69s - loss: 0.0129 - accuracy: 0.9965 - val_loss: 0.2607 - val_accuracy: 0.9207 - lr: 3.1623e-07 - 69s/epoch - 435ms/step
# Epoch 48/50
# 159/159 - 69s - loss: 0.0126 - accuracy: 0.9957 - val_loss: 0.2605 - val_accuracy: 0.9207 - lr: 1.0000e-07 - 69s/epoch - 436ms/step
# Epoch 49/50
# 159/159 - 69s - loss: 0.0126 - accuracy: 0.9965 - val_loss: 0.2605 - val_accuracy: 0.9207 - lr: 1.0000e-07 - 69s/epoch - 432ms/step
# Epoch 50/50
# 159/159 - 69s - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.2602 - val_accuracy: 0.9207 - lr: 1.0000e-07 - 69s/epoch - 432ms/step

# %% [markdown]
# ### **5. Plotting the Model Metrics**

# %% [markdown]
# #### **i. Plotting training and validation accuracy, loss and learning rate**

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **6. Testing the Model on Test Set**

# %% [markdown]
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/kaggle/input/pothole-data/My_Dataset/test/'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 1021 images belonging to 2 classes.

# %% [markdown]
# ### **7. Model Prediction on the Test Dataset**

# %%
predictions = model.predict(test_generator)
# Out:
# 32/32 [==============================] - 5s 138ms/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 32/32 [==============================] - 4s 130ms/step - loss: 0.2602 - accuracy: 0.9207

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.2602291405200958
# Test Accuracy: 0.9206660389900208

# %% [markdown]
# The test loss and test accuracy is the same as validation loss and validation accuracy at the last step since the testing and validation datasets are same.

# %% [markdown]
# ### **8. Plotting the Classification Metrics**

# %% [markdown]
# ### **i. Confusion Matrix**

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
from sklearn.metrics import classification_report,accuracy_score,precision_score
from sklearn.metrics import confusion_matrix,roc_curve,recall_score,f1_score,roc_auc_score
print(classification_report(y_true, y_pred, target_names=labels.values()))
print('The accuracy of InceptionResNetV2 is: ' , 100.0 * test_accuracy)
print('precision: ', 100.0*precision_score(y_true, y_pred,pos_label='positive'
                                           ,average='weighted'))
print('recall: ',100.0* recall_score(y_true, y_pred,pos_label='positive'
                                           ,average='weighted'))
print('f1-score: ',100.0*f1_score(y_true, y_pred,pos_label='positive'
                                           ,average='weighted'))
# Out:
#               precision    recall  f1-score   support
#
#        Plain       1.00      0.84      0.91       509
#      Pothole       0.86      1.00      0.93       512
#
#     accuracy                           0.92      1021
#    macro avg       0.93      0.92      0.92      1021
# weighted avg       0.93      0.92      0.92      1021
#
# The accuracy of InceptionResNetV2 is:  92.06660389900208
# precision:  93.0959861404967
# recall:  92.0666013712047
# f1-score:  92.01698110204109

# %% [markdown]
# ### **9. Wrong Predictions**
#
# Let's see where the model has given wrong predictions and what were the actual predictions on those images.

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
