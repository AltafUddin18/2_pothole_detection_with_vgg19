# %% [markdown]
# ### **1. Import the Required Libraries**

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from tensorflow import keras
from tensorflow.keras import layers
import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# ### **2. Load the Image Training and Validation Datasets**

# %% [markdown]
# #### **i. Get the Image Dataset Paths**

# %%
train_dataset_path = '/kaggle/input/pothole-data/My_Dataset/train/'
validation_dataset_path = '/kaggle/input/pothole-data/My_Dataset/test/'

# %% [markdown]
# #### **ii. Load Image Datasets and Apply Augmentations**

# %% [markdown]
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32
image_size = (128,128)

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 5075 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 1021 images belonging to 2 classes.

# %% [markdown]
# #### **iii. Get the Label Mappings**

# %% [markdown]
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Plain
# 1 : Pothole

# %% [markdown]
# ### **3. Plotting Sample Training Images**

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ### **4. Training a VGG16 Model**

# %% [markdown]
# Since the training dataset is ready let's create a simple VGG19 Model to train on the image datasets

# %% [markdown]
# #### **i. Create a VGG19 Build Model**

# %%
base_model = keras.applications.VGG19(include_top=False,input_shape=image_size+(3,))
base_model.trainable = False

model = keras.Sequential([
    base_model,
    layers.Flatten(),
    layers.Dense(2,activation='sigmoid')
])

model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.BinaryCrossentropy(),
    metrics=[keras.metrics.BinaryAccuracy()]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 2)                 16386
#
# =================================================================
# Total params: 20,040,770
# Trainable params: 16,386
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, expand_nested=True, show_shapes=True, show_layer_names=False)

# %% [markdown]
# #### **ii. Defining Callbacks**

# %% [markdown]
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)

# %% [markdown]
# #### **a. Reduce Learning Rate on Plateau**
#
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %% [markdown]
# #### **iii. Defining the Optimizer**

# %%
optimizer = Adam(learning_rate=0.001)

# %% [markdown]
# #### **iv. Compile the Model**

# %%
model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %% [markdown]
# #### **v. Training the Model**

# %%
# training
history = model.fit(train_generator,batch_size=32,epochs=50,
        validation_data=validation_generator,verbose=2,
                       callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 159/159 - 138s - loss: 0.0748 - accuracy: 0.9750 - val_loss: 0.2723 - val_accuracy: 0.9089 - lr: 0.0010 - 138s/epoch - 868ms/step
# Epoch 2/50
# 159/159 - 70s - loss: 0.0282 - accuracy: 0.9913 - val_loss: 0.3878 - val_accuracy: 0.8864 - lr: 0.0010 - 70s/epoch - 441ms/step
# Epoch 3/50
# 159/159 - 70s - loss: 0.0245 - accuracy: 0.9919 - val_loss: 0.3128 - val_accuracy: 0.9079 - lr: 0.0010 - 70s/epoch - 438ms/step
# Epoch 4/50
# 159/159 - 69s - loss: 0.0207 - accuracy: 0.9937 - val_loss: 0.3639 - val_accuracy: 0.9011 - lr: 0.0010 - 69s/epoch - 433ms/step
# Epoch 5/50
# 159/159 - 69s - loss: 0.0152 - accuracy: 0.9957 - val_loss: 0.2610 - val_accuracy: 0.9275 - lr: 0.0010 - 69s/epoch - 433ms/step
# Epoch 6/50
# 159/159 - 69s - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.3171 - val_accuracy: 0.9158 - lr: 0.0010 - 69s/epoch - 435ms/step
# Epoch 7/50
# 159/159 - 68s - loss: 0.0096 - accuracy: 0.9967 - val_loss: 0.3131 - val_accuracy: 0.9207 - lr: 0.0010 - 68s/epoch - 427ms/step
# Epoch 8/50
# 159/159 - 69s - loss: 0.0130 - accuracy: 0.9953 - val_loss: 0.2621 - val_accuracy: 0.9295 - lr: 0.0010 - 69s/epoch - 432ms/step
# Epoch 9/50
# 159/159 - 68s - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.3733 - val_accuracy: 0.9070 - lr: 0.0010 - 68s/epoch - 429ms/step
# Epoch 10/50
# 159/159 - 68s - loss: 0.0092 - accuracy: 0.9976 - val_loss: 0.5646 - val_accuracy: 0.8776 - lr: 0.0010 - 68s/epoch - 431ms/step
# Epoch 11/50
# 159/159 - 68s - loss: 0.0064 - accuracy: 0.9982 - val_loss: 0.3295 - val_accuracy: 0.9158 - lr: 3.1623e-04 - 68s/epoch - 429ms/step
# Epoch 12/50
# 159/159 - 68s - loss: 0.0057 - accuracy: 0.9982 - val_loss: 0.3623 - val_accuracy: 0.9109 - lr: 3.1623e-04 - 68s/epoch - 430ms/step
# Epoch 13/50
# 159/159 - 68s - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.2249 - val_accuracy: 0.9412 - lr: 3.1623e-04 - 68s/epoch - 431ms/step
# Epoch 14/50
# 159/159 - 68s - loss: 0.0048 - accuracy: 0.9990 - val_loss: 0.2119 - val_accuracy: 0.9452 - lr: 3.1623e-04 - 68s/epoch - 430ms/step
# Epoch 15/50
# 159/159 - 68s - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.1957 - val_accuracy: 0.9500 - lr: 3.1623e-04 - 68s/epoch - 430ms/step
# Epoch 16/50
# 159/159 - 68s - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.2040 - val_accuracy: 0.9491 - lr: 3.1623e-04 - 68s/epoch - 426ms/step
# Epoch 17/50
# 159/159 - 69s - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.2497 - val_accuracy: 0.9324 - lr: 3.1623e-04 - 69s/epoch - 432ms/step
# Epoch 18/50
# 159/159 - 68s - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.2450 - val_accuracy: 0.9354 - lr: 3.1623e-04 - 68s/epoch - 427ms/step
# Epoch 19/50
# 159/159 - 68s - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.2686 - val_accuracy: 0.9305 - lr: 3.1623e-04 - 68s/epoch - 427ms/step
# Epoch 20/50
# 159/159 - 68s - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.2739 - val_accuracy: 0.9334 - lr: 3.1623e-04 - 68s/epoch - 428ms/step
# Epoch 21/50
# 159/159 - 68s - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.2595 - val_accuracy: 0.9363 - lr: 1.0000e-04 - 68s/epoch - 427ms/step
# Epoch 22/50
# 159/159 - 68s - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.2900 - val_accuracy: 0.9305 - lr: 1.0000e-04 - 68s/epoch - 427ms/step
# Epoch 23/50
# 159/159 - 69s - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.3192 - val_accuracy: 0.9265 - lr: 1.0000e-04 - 69s/epoch - 431ms/step
# Epoch 24/50
# 159/159 - 69s - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.2361 - val_accuracy: 0.9461 - lr: 1.0000e-04 - 69s/epoch - 431ms/step
# Epoch 25/50
# 159/159 - 68s - loss: 0.0047 - accuracy: 0.9992 - val_loss: 0.3142 - val_accuracy: 0.9265 - lr: 1.0000e-04 - 68s/epoch - 426ms/step
# Epoch 26/50
# 159/159 - 69s - loss: 0.0050 - accuracy: 0.9992 - val_loss: 0.2752 - val_accuracy: 0.9344 - lr: 3.1623e-05 - 69s/epoch - 431ms/step
# Epoch 27/50
# 159/159 - 67s - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.2940 - val_accuracy: 0.9295 - lr: 3.1623e-05 - 67s/epoch - 420ms/step
# Epoch 28/50
# 159/159 - 67s - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.2886 - val_accuracy: 0.9314 - lr: 3.1623e-05 - 67s/epoch - 419ms/step
# Epoch 29/50
# 159/159 - 67s - loss: 0.0048 - accuracy: 0.9992 - val_loss: 0.3241 - val_accuracy: 0.9246 - lr: 3.1623e-05 - 67s/epoch - 423ms/step
# Epoch 30/50
# 159/159 - 67s - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.2843 - val_accuracy: 0.9305 - lr: 3.1623e-05 - 67s/epoch - 423ms/step
# Epoch 31/50
# 159/159 - 68s - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.2884 - val_accuracy: 0.9295 - lr: 1.0000e-05 - 68s/epoch - 427ms/step
# Epoch 32/50
# 159/159 - 68s - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.2828 - val_accuracy: 0.9324 - lr: 1.0000e-05 - 68s/epoch - 429ms/step
# Epoch 33/50
# 159/159 - 68s - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.2791 - val_accuracy: 0.9324 - lr: 1.0000e-05 - 68s/epoch - 426ms/step
# Epoch 34/50
# 159/159 - 69s - loss: 0.0024 - accuracy: 0.9998 - val_loss: 0.2865 - val_accuracy: 0.9295 - lr: 1.0000e-05 - 69s/epoch - 433ms/step
# Epoch 35/50
# 159/159 - 68s - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.2810 - val_accuracy: 0.9324 - lr: 1.0000e-05 - 68s/epoch - 429ms/step
# Epoch 36/50
# 159/159 - 67s - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.2846 - val_accuracy: 0.9324 - lr: 3.1623e-06 - 67s/epoch - 424ms/step
# Epoch 37/50
# 159/159 - 68s - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.2884 - val_accuracy: 0.9295 - lr: 3.1623e-06 - 68s/epoch - 426ms/step
# Epoch 38/50
# 159/159 - 68s - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.2827 - val_accuracy: 0.9334 - lr: 3.1623e-06 - 68s/epoch - 425ms/step
# Epoch 39/50
# 159/159 - 67s - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.2804 - val_accuracy: 0.9324 - lr: 3.1623e-06 - 67s/epoch - 422ms/step
# Epoch 40/50
# 159/159 - 69s - loss: 0.0046 - accuracy: 0.9994 - val_loss: 0.2787 - val_accuracy: 0.9324 - lr: 3.1623e-06 - 69s/epoch - 436ms/step
# Epoch 41/50
# 159/159 - 71s - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.2786 - val_accuracy: 0.9324 - lr: 1.0000e-06 - 71s/epoch - 445ms/step
# Epoch 42/50
# 159/159 - 69s - loss: 0.0040 - accuracy: 0.9992 - val_loss: 0.2787 - val_accuracy: 0.9324 - lr: 1.0000e-06 - 69s/epoch - 433ms/step
# Epoch 43/50
# 159/159 - 68s - loss: 0.0042 - accuracy: 0.9992 - val_loss: 0.2803 - val_accuracy: 0.9324 - lr: 1.0000e-06 - 68s/epoch - 428ms/step
# Epoch 44/50
# 159/159 - 68s - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.2814 - val_accuracy: 0.9324 - lr: 1.0000e-06 - 68s/epoch - 431ms/step
# Epoch 45/50
# 159/159 - 69s - loss: 0.0044 - accuracy: 0.9992 - val_loss: 0.2810 - val_accuracy: 0.9324 - lr: 1.0000e-06 - 69s/epoch - 433ms/step
# Epoch 46/50
# 159/159 - 68s - loss: 0.0025 - accuracy: 0.9996 - val_loss: 0.2815 - val_accuracy: 0.9324 - lr: 3.1623e-07 - 68s/epoch - 430ms/step
# Epoch 47/50
# 159/159 - 68s - loss: 0.0036 - accuracy: 0.9994 - val_loss: 0.2815 - val_accuracy: 0.9324 - lr: 3.1623e-07 - 68s/epoch - 426ms/step
# Epoch 48/50
# 159/159 - 68s - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.2809 - val_accuracy: 0.9324 - lr: 3.1623e-07 - 68s/epoch - 427ms/step
# Epoch 49/50
# 159/159 - 69s - loss: 0.0047 - accuracy: 0.9994 - val_loss: 0.2809 - val_accuracy: 0.9324 - lr: 3.1623e-07 - 69s/epoch - 432ms/step
# Epoch 50/50
# 159/159 - 68s - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.2802 - val_accuracy: 0.9324 - lr: 3.1623e-07 - 68s/epoch - 428ms/step

# %% [markdown]
# ### **5. Plotting the Model Metrics**

# %% [markdown]
# #### **i. Plotting training and validation accuracy, loss and learning rate**

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **6. Testing the Model on Test Set**

# %% [markdown]
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/kaggle/input/pothole-data/My_Dataset/test/'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 1021 images belonging to 2 classes.

# %% [markdown]
# ### **7. Model Prediction on the Test Dataset**

# %%
predictions = model.predict(test_generator)
# Out:
# 32/32 [==============================] - 5s 140ms/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 32/32 [==============================] - 5s 139ms/step - loss: 0.2802 - accuracy: 0.9324

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.28022801876068115
# Test Accuracy: 0.9324191808700562

# %% [markdown]
# The test loss and test accuracy is the same as validation loss and validation accuracy at the last step since the testing and validation datasets are same.

# %% [markdown]
# ### **8. Plotting the Classification Metrics**

# %% [markdown]
# ### **i. Confusion Matrix**

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#        Plain       1.00      0.87      0.93       509
#      Pothole       0.88      1.00      0.94       512
#
#     accuracy                           0.93      1021
#    macro avg       0.94      0.93      0.93      1021
# weighted avg       0.94      0.93      0.93      1021

# %% [markdown]
# ### **9. Wrong Predictions**
#
# Let's see where the model has given wrong predictions and what were the actual predictions on those images.

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
